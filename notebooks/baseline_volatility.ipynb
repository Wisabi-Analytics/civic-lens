# %% [markdown]
# # civic-lens: Baseline Volatility Analysis
#
# Phase B — Task B2/B3
#
# Computes all six metrics for 2018→2022 and 2022→2025 transitions.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../models')

from metrics import (vote_share_swing, turnout_delta, fragmentation_index,
                     seat_change, volatility_score, swing_concentration)

# Load clean data
df = pd.read_csv('../data/processed/clean_election_results.csv')
print(df.shape)
df.head()
