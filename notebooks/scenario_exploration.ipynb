# %% [markdown]
# # civic-lens: Scenario Validation
#
# Phase B — Task B7/B8
#
# Validates scenario outputs: interval sanity, coverage checks.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../models')

from scenario_model import run_all_scenarios, validate_outputs

scenario_outputs = pd.read_csv('../data/processed/scenario_outputs.csv')
validate_outputs(scenario_outputs)
